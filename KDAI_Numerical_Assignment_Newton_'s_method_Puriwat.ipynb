# %% [markdown]
# <a href="https://colab.research.google.com/github/Pongpang-2102/Numerical-Computation-and-Optimization-Models_KDAI-Project/blob/main/KDAI_Numerical_Assignment_Newton_'s_method_Puriwat.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Homework 4 : Newton 's Method

# %%
# import package
import math

# %% [markdown]
# ## 01

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %%
# Definining function
def f(x) :
    return (x ** 4) - 5*(x**3) + 9*x + 3

# Defining derivative of function
def g(x) :
    return 4*(x**3) - 15*(x**2) + 9

# Defining Newton Method
def newtonRaphson(x0,e,N) :
    print('\n\n*** NEWTON METHOD IMPLEMENTATION')
    step = 1 
    flag = 1
    condition = True
    while condition:
        if g(x0) == 0.0:
            print("Divide by zero error!")
            break

        x1 = x0 - f(x0)/g(x0)
        print('Iteration : %d, x1 = %0.6f and f(x1) = %0.6f' %(step, x1 , f(x1) ))
        x0 = x1
        step = step + 1

        if step > N:
            flag = 0 
            break

        condition =  abs(f(x1)) > e

    if flag == 1:
        print('\nRequired root is : %0.8f' %x1)
    
    else :
        print('\nNot Convergent.')



# input section
x0 = input('Initial Guess : ')
e = input('Tolerable Error : ')
N = input('Maximum Step : ')


# Converting x0 and e to Float
x0 = float(x0)
e = float(e)


# Converting N to Integer
N = int(N)

# Starting Newton Method 
newtonRaphson(x0,e,N)
# Out:
# Initial Guess : 5
# Tolerable Error : 0.0000001
# Maximum Step : 20
#
#
# *** NEWTON METHOD IMPLEMENTATION
# Iteration : 1, x1 = 4.641791 and f(x1) = 8.950542
# Iteration : 2, x1 = 4.537544 and f(x1) = 0.632997
# Iteration : 3, x1 = 4.528974 and f(x1) = 0.004066
# Iteration : 4, x1 = 4.528918 and f(x1) = 0.000000
# Iteration : 5, x1 = 4.528918 and f(x1) = 0.000000
#
# Required root is : 4.52891796

# %% [markdown]
# - After program is being run , the result would be.....

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ## 02

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %%
# Definining function
def f(x) :
    return 2*(x ** 2) + 5 - (math.e**x)

# Defining derivative of function
def g(x) :
    return 4*x - (math.e**x)

# Defining Newton Method
def newtonRaphson(x0,e,N) :
    print('\n\n*** NEWTON METHOD IMPLEMENTATION')
    step = 1 
    flag = 1
    condition = True
    while condition:
        if g(x0) == 0.0:
            print("Divide by zero error!")
            break

        x1 = x0 - f(x0)/g(x0)
        print('Iteration : %d, x1 = %0.6f and f(x1) = %0.6f' %(step, x1 , f(x1) ))
        x0 = x1
        step = step + 1

        if step > N:
            flag = 0 
            break

        condition =  abs(f(x1)) > e

    if flag == 1:
        print('\nRequired root is : %0.8f' %x1)
    
    else :
        print('\nNot Convergent.')



# input section
x0 = input('Initial Guess : ')
e = input('Tolerable Error : ')
N = input('Maximum Step : ')


# Converting x0 and e to Float
x0 = float(x0)
e = float(e)


# Converting N to Integer
N = int(N)

# Starting Newton Method 
newtonRaphson(x0,e,N)
# Out:
# Initial Guess : 3.5
# Tolerable Error : 0.000001
# Maximum Step : 30
#
#
# *** NEWTON METHOD IMPLEMENTATION
# Iteration : 1, x1 = 3.310862 and f(x1) = -0.485132
# Iteration : 2, x1 = 3.276614 and f(x1) = -0.013546
# Iteration : 3, x1 = 3.275602 and f(x1) = -0.000012
# Iteration : 4, x1 = 3.275601 and f(x1) = -0.000000
#
# Required root is : 3.27560109

# %% [markdown]
# - After program is being run , the result would be.....

# %% [markdown]
# ![image.png](data:image/png;base64,...)
